# %%
import pandas as pd
import numpy as np

# %%
# Membaca dataset
df = pd.read_csv('covid_19_indonesia_time_series_all.csv')
df.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            2             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               41  ... -6.204699                  0.18
# 1               41  ... -6.204699                  0.18
# ...

# %%
# Melihat informasi tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21759 entries, 0 to 21758
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         21759 non-null  object
#  1   Location ISO Code            21759 non-null  object
#  2   Location                     21759 non-null  object
#  3   New Cases                    21759 non-null  int64
#  4   New Deaths                   21759 non-null  int64
#  5   New Recovered                21759 non-null  int64
#  6   New Active Cases             21759 non-null  int64
#  7   Total Cases                  21759 non-null  int64
#  8   Total Deaths                 21759 non-null  int64
#  9   Total Recovered              21759 non-null  int64
#  10  Total Active Cases           21759 non-null  int64
#  11  Location Level               21759 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
# Melihat nama kolom
df.columns
# Out:
# Index(['Date', 'Location ISO Code', 'Location', 'New Cases', 'New Deaths',
#        'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths',
#        'Total Recovered', 'Total Active Cases', 'Location Level',
#        'City or Regency', 'Province', 'Country', 'Continent', 'Island',
#        'Time Zone', 'Special Status', 'Total Regencies', 'Total Cities',
#        'Total Districts', 'Total Urban Villages', 'Total Rural Villages',
#        'Area (km2)', 'Population', 'Population Density', 'Longitude',
#        'Latitude', 'New Cases per Million', 'Total Cases per Million',
#        'New Deaths per Million', 'Total Deaths per Million',
#        'Total Deaths per 100rb', 'Case Fatality Rate', 'Case Recovered Rate',
#        'Growth Factor of New Cases', 'Growth Factor of New Deaths'],
#       dtype='object')

# %%
# Menampilkan kolom missing values
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            2             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               41  ... -6.204699                  0.18
# 1               41  ... -6.204699                  0.18
# ...

# %%
# Cek nilai berdasarkan tipe data
df.select_dtypes('object')
# Out:
#             Date Location ISO Code          Location Location Level  \
# 0       3/1/2020             ID-JK       DKI Jakarta       Province
# 1       3/2/2020             ID-JK       DKI Jakarta       Province
# 2       3/2/2020               IDN         Indonesia        Country
# 3       3/2/2020             ID-RI              Riau       Province
# 4       3/3/2020             ID-JK       DKI Jakarta       Province
# ...          ...               ...               ...            ...
# 21754  12/2/2021             ID-SA    Sulawesi Utara       Province
# 21755  12/2/2021             ID-SB    Sumatera Barat       Province
# 21756  12/2/2021             ID-SS  Sumatera Selatan       Province
# 21757  12/2/2021             ID-SU    Sumatera Utara       Province
# 21758  12/3/2021               IDN         Indonesia        Country
#
#                Province    Country Continent    Island  Time Zone  \
# 0           DKI Jakarta  Indonesia      Asia      Jawa  UTC+07:00
# ...

# %%
# Cek nilai berdasarkan tipe data
df.select_dtypes('int64')
# Out:
#        New Cases  New Deaths  New Recovered  New Active Cases  Total Cases  \
# 0              2           0              0                 2           39
# 1              2           0              0                 2           41
# 2              2           0              0                 2            2
# 3              1           0              0                 1            2
# 4              2           0              0                 2           43
# ...          ...         ...            ...               ...          ...
# 21754          2           0              0                 2        34715
# 21755          4           0              0                 4        89849
# 21756          4           0              0                 4        59937
# 21757          4           0              1                 3       106045
# 21758        245           8            328               -91      4257243
#
# ...

# %%
# Cek nilai berdasarkan tipe data
df.select_dtypes('float64')
# Out:
#        City or Regency  Total Cities  Total Urban Villages  \
# 0                  NaN           5.0                 267.0
# 1                  NaN           5.0                 267.0
# 2                  NaN          98.0                8488.0
# 3                  NaN           2.0                 268.0
# 4                  NaN           5.0                 267.0
# ...                ...           ...                   ...
# 21754              NaN           4.0                 332.0
# 21755              NaN           7.0                 230.0
# 21756              NaN           4.0                 387.0
# 21757              NaN           8.0                 693.0
# 21758              NaN          98.0                8488.0
#
#        Total Rural Villages  Population Density   Longitude  Latitude  \
# 0                       NaN            16334.31  106.836118 -6.204699
# 1                       NaN            16334.31  106.836118 -6.204699
# ...

# %%
df.drop(["Location ISO Code", "New Cases", "New Deaths", "New Recovered", "New Active Cases", "Province", "Country", "Continent", "Island", "Time Zone", 
                "Special Status", "Total Regencies", "Total Cities", "Total Districts", "Total Urban Villages", "Total Rural Villages", "Area (km2)", 
                "New Cases per Million", "Total Cases per Million","New Deaths per Million", "Total Deaths per Million", "Case Fatality Rate",
                "Case Recovered Rate", "Growth Factor of New Cases","Growth Factor of New Deaths", "City or Regency"],axis=1,inplace=True)

# %%
df.drop(df[(df['Location']=='Indonesia')].index,inplace=True)

# %%
# Membuat index baru
df = df.reset_index()

# %%
# Menghapus index lama
df = df.drop(columns='index')

# %%
# Menyimpan file terbaru
df.to_excel('dataclean_c-19.xlsx')

# %% [markdown]
# --------------------------------------------------Lanjut Ke Visualisasi Tableau, Gambar Link Tableau Pada Kolom Read.Me------------------------------------------------------
